# %% [markdown]
# <a href="https://colab.research.google.com/github/btg1631/study_AIs/blob/main/docs/quests/NLPs/wordcloud_regexp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## wordcloud

# %%
import pandas as pd
import numpy as np

df_OWG = pd.read_excel('OneWord_Game.xlsx', sheet_name=None)

# %%
df_all = pd.concat(df_OWG.values(), axis=1)
df_OWG_text = df_all.loc[13]
df_OWG_text
# Out:
#                                                                      장영지
# Unnamed: 1                         자연어 처리(Natural Language Processing)\n
# 2024-02-15 00:00:00    스케일링\n서로 다른 범위의 값을 가진 데이터들의 범위를 표준화시키는 과정이다. 머...
# 2024-02-14 00:00:00    pickle\n파이썬 객체 자체를 이진파일로 저장하는 파이썬 모듈이다. 대량의 데이...
# 2024-02-13 00:00:00    머신러닝\n컴퓨터가 데이터를 학습해서 규칙을 찾아내는 과정이다. 머신러닝 모델이 학...
# 2024-02-07 00:00:00    정규성 검증\n데이터가 정규 분포를 따르는지 여부를 확인하는 과정이다. 데이터의 분...
# 2024-02-06 00:00:00    귀무가설\n처음부터 기각할 것을 예상하고 세우는 가설이다. 차이가 없거나 유의미한 ...
# 2024-02-05 00:00:00    pandas.concat\n동일한 컬럼 구조를 가진 시리즈나 데이터프레임을 하나의 ...
# 2024-02-02 00:00:00    이상치\n데이터 값 중 일반적인 분포에서 크게 벗어난 값을 의미하며, 이상치를 식별...
# 2024-02-01 00:00:00    datetime\n날짜와 시간을 처리할 수 있는 클래스와 함수를 제공하는 파이썬 모...
#                                                                      장영지
# 2024-01-31 00:00:00    value_counts()\npandas에서 Series의 각 유일한 값들의 출현 ...
# 2024-01-30 00:00:00    Matplotlib\n파이썬에서 데이터를 그래프나 차트로 표현하여 시각화하는 라이브...
# 2024-01-29 00:00:00    Pandas\n파이썬에서 데이터 분석을 위해 사용되는 라이브러리이다. 대량의 데이터...
# 2024-01-26 00:00:00    DataFrame\n2차원 배열 형태의 데이터 구조로, 여러 개의 Series가 모...
# 1월 25일                 자바스크립트\n브라우저에서 사용하는 자바스크립트는 웹 페이지를 동적이고 상호작용 가...
# 1월 24일                 postman\nAPI 개발을 위한 테스트 및 문서화를 도와주는 플랫폼이다. 그 목...
# 1월 23일                 Open API\n누구나 사용할 수 있도록 공개된 API이다. 이를 통해 복잡한 기...
# 1월 22일                                                               NaN
# 1월 19일                                                               NaN
# 1월 18일                           Uvicorn\n비동기 처리 방식을 지원하는 Python 웹 서버이다.
# 1월 17일                 HTTP\n웹상에서 클라이언트와 서버 간에 요청/응답으로 데이터를 주고 받을 수 있...
# 1월 16일                 commit\n파일의 변경사항을 저장하는 작업이다.\n그 목적은 코드 변경 이력을 ...
# 1월 15일                 데이터베이스 시스템\n데이터를 데이터베이스에 저장하고 관리하는 시스템이다.\n그 목...
# 1월 12일                 데이터 조작어\n데이터베이스 안의 데이터를 조작할 때 쓰는 명령어의 집합이다.\n데...
# 1월 11일                 데이터 종속성\n데이터와 응용 프로그램이 상호 의존 관계를 말하며, 데이터의 구조가...
# 1월 10일                 스타일 상속\n자식 요소에서 별도로 스타일을 지정하지 않으면 부모 요소의 스타일 속...
# 1월 9일                  반응형 웹 디자인\n웹 브라우저의 크기에 따라 화면 레이아웃을 자동으로 바꿔주는 방...
# 1월 8일                     프레임워크\n어떤 일을 처리하기위해 필요한 클래스와 라이브러리등이 합쳐진 형태이다.
# 1월 5일                            await \n작업 처리가 완료될때까지 코드 실행을 중지하고 기다린다.
# 1월 4일                  WAS(Web Application Server)\n웹 서버와 다르게 데이터베이스 ...
# 1월 3일                       fastAPI\n파이썬으로 API를 구축할 수 있게 해주는 웹 프레임워크이다\n
# 1월 2일                                                                NaN
#                                                                      장영지
# 12월 29일                select_by_index\nselect 태그에서 특정 인덱스의 옵션을 선택하는데...
# 12월 28일                iframe\n웹 페이지 내에 다른 웹 페이지를 포함시키기 위해 사용하는 HTML ...
# 12월 27일                scrollHeight\n웹 스크래핑 할 때 웹 페이지를 끝까지 스크롤 다운해야 그...
# 12월 26일                       parsing\n웹 페이지에서 내가 원하는 특정한 정보를 추출하는 기술이다.
# 12월 22일                           Wep Scraping \n웹 페이지의 정보를 수집하는 작업이다.\n
# 12월 21일                디버깅 순서\n구문 오류 확인, 변수 오류 확인, 업무 오류 확인(반복 입력 자동화...
# 12월 20일                __name__\n파이썬 파일을 직접 실행할 경우 __name__에 __main__...
# 12월 19일                                 exception\n코드를 실행하는 중에 발생한 에러이다.
# 12월 18일                cursor\nmongodb에서 collection의 내용을 찾을 때 그 위치값을 ...
# 12월 15일                     Object Id\ndb에 데이터를 입력하면 자동으로 생성되고 수정이 불가하다.
# 12월 14일                CRUD\nCreate, Read, Update, Delete 4가지의 데이터 처리...
# 12월 13일                import\n만들어져 있는 모듈을 다른 파이썬 파일에서 사용할 수 있게 해주는 명...
# 12월 12일                논리연산자\nTrue인지 False인지 판단하는 연산자로\nand, or, not ...
# 12월 11일                git 충돌\n같은 라인에 여러명이 동시에 작업을 했을 시, 충돌이 일어나고, 이를...
# Name: 13, dtype: object

# %%
df_sheets = []
for sheet_name, df in df_OWG_text.items():
  df_sheets.append(df)
  print(f'{sheet_name}, {type(df)}')
  pass
# Out:
#             , <class 'str'>
# Unnamed: 1, <class 'str'>
# 2024-02-15 00:00:00, <class 'str'>
# 2024-02-14 00:00:00, <class 'str'>
# 2024-02-13 00:00:00, <class 'str'>
# 2024-02-07 00:00:00, <class 'str'>
# 2024-02-06 00:00:00, <class 'str'>
# 2024-02-05 00:00:00, <class 'str'>
# 2024-02-02 00:00:00, <class 'str'>
# 2024-02-01 00:00:00, <class 'str'>
#             , <class 'str'>
# 2024-01-31 00:00:00, <class 'str'>
# 2024-01-30 00:00:00, <class 'str'>
# 2024-01-29 00:00:00, <class 'str'>
# 2024-01-26 00:00:00, <class 'str'>
# 1월 25일, <class 'str'>
# 1월 24일, <class 'str'>
# 1월 23일, <class 'str'>
# 1월 22일, <class 'float'>
# 1월 19일, <class 'float'>
# 1월 18일, <class 'str'>
# 1월 17일, <class 'str'>
# 1월 16일, <class 'str'>
# 1월 15일, <class 'str'>
# 1월 12일, <class 'str'>
# 1월 11일, <class 'str'>
# 1월 10일, <class 'str'>
# 1월 9일, <class 'str'>
# 1월 8일, <class 'str'>
# 1월 5일, <class 'str'>
# 1월 4일, <class 'str'>
# 1월 3일, <class 'str'>
# 1월 2일, <class 'float'>
#       , <class 'str'>
# 12월 29일, <class 'str'>
# 12월 28일, <class 'str'>
# 12월 27일, <class 'str'>
# 12월 26일, <class 'str'>
# 12월 22일, <class 'str'>
# 12월 21일, <class 'str'>
# 12월 20일, <class 'str'>
# 12월 19일, <class 'str'>
# 12월 18일, <class 'str'>
# 12월 15일, <class 'str'>
# 12월 14일, <class 'str'>
# 12월 13일, <class 'str'>
# 12월 12일, <class 'str'>
# 12월 11일, <class 'str'>

# %%
text = ' '.join(map(str, df_sheets))
text
# Out:
# '장영지 자연어 처리(Natural Language Processing)\n 스케일링\n서로 다른 범위의 값을 가진 데이터들의 범위를 표준화시키는 과정이다. 머신러닝 모델이 특정 데이터에 편향되어 학습하는 것을 방지할 수 있다. pickle\n파이썬 객체 자체를 이진파일로 저장하는 파이썬 모듈이다. 대량의 데이터를 사용하거나 복잡한 계산을 처리해야할 때 그 결과를 저장해 필요할 때 다시 불러올 수 있다. 머신러닝\n컴퓨터가 데이터를 학습해서 규칙을 찾아내는 과정이다. 머신러닝 모델이 학습을 완료하면, 그 모델 자체로서 다양한 판단이나 예측을 수행할 수 있게 된다. 정규성 검증\n데이터가 정규 분포를 따르는지 여부를 확인하는 과정이다. 데이터의 분포 형태를 확인해서, 이후에 진행할 테스트가 적절한지를 판단한다. 귀무가설\n처음부터 기각할 것을 예상하고 세우는 가설이다. 차이가 없거나 유의미한 차이가 없는 경우.\n대립가설이 참임을 증명하기 위해 사용한다. pandas.concat\n동일한 컬럼 구조를 가진 시리즈나 데이터프레임을 하나의 데이터셋으로 합칠 때 사용하는 함수이다. 이상치\n데이터 값 중 일반적인 분포에서 크게 벗어난 값을 의미하며, 이상치를 식별하는 목적은 정확한 분석을 위해 이러한 값들이 데이터에 미치는 영향을 최소화하기 위함이다. datetime\n날짜와 시간을 처리할 수 있는 클래스와 함수를 제공하는 파이썬 모듈이다. 이를 사용하면 문자열 형태의 날짜 데이터를 실제 datetime 타입으로 변환하여 분석할 수 있다. 장영지 value_counts()\npandas에서 Series의 각 유일한 값들의 출현 빈도를 계산하는 함수이다. 데이터의 분포를 파악하거나, 가장 자주 나타나는 값을 확인할 때 사용된다.\n범주형 데이터를 파악할 때 사용 Matplotlib\n파이썬에서 데이터를 그래프나 차트로 표현하여 시각화하는 라이브러리이다. 데이터 분석 결과를 한눈에 이해하고 데이터의 패턴을 파악하기 위해 사용한다. Pandas\n파이썬에서 데이터 분석을 위해 사용되는 라이브러리이다. 대량의 데이터를 빠르게 처리, 분석하기 위해 사용한다. 판다스 외에 데이터 분석을 위해 사용하는 라이브러리에는 NumPy, sklearn 등이 있다. DataFrame\n2차원 배열 형태의 데이터 구조로, 여러 개의 Series가 모여서 행과 열을 이루는 형태이다. 각 열마다 다른 데이터 타입을 가질 수 있으므로, 여러 가지 타입의 데이터를 한 번에 다루는 데 효과적이다. 자바스크립트\n브라우저에서 사용하는 자바스크립트는 웹 페이지를 동적이고 상호작용 가능하게 만드는 프로그래밍 언어이다. 클라이언트 측에서 코드를 실행하여 서버의 부하를 감소시키기 위해 사용한다. postman\nAPI 개발을 위한 테스트 및 문서화를 도와주는 플랫폼이다. 그 목적은 서버가 들어온 API 요청에 대해서 제대로 동작하는지 확인하기 위함이다. Open API\n누구나 사용할 수 있도록 공개된 API이다. 이를 통해 복잡한 기능을 빠르게 구현하거나, 다른 서비스와의 연동을 간편하게 처리할 수 있어, 개발 시간을 단축하고 효율성을 높일 수 있다. nan nan Uvicorn\n비동기 처리 방식을 지원하는 Python 웹 서버이다. HTTP\n웹상에서 클라이언트와 서버 간에 요청/응답으로 데이터를 주고 받을 수 있는 프로토콜이다. 클라이언트와 서버 간에, 혹은 서버와 서버 간에 데이터를 신속하고 안전하게 교환하는 것이다. 웹 브라우저, 애플리케이션, 다른 서버 등 다양한 환경에서의 통신에 사용된다. commit\n파일의 변경사항을 저장하는 작업이다.\n그 목적은 코드 변경 이력을 관리하고 추적하여 버전관리와 협업을 지원하는 것이다. 데이터베이스 시스템\n데이터를 데이터베이스에 저장하고 관리하는 시스템이다.\n그 목적은 파일 시스템의 문제점인 데이터 종속성과 데이터 중복성을 최소화 하고, 데이터를 효율적으로 관리하기 위함이다. 데이터 조작어\n데이터베이스 안의 데이터를 조작할 때 쓰는 명령어의 집합이다.\n데이터 조작어의 주요 목적은 데이터베이스에서 정보를 삽입, 삭제, 갱신, 검색하는 것이다. 이를 통해 사용자는 필요한 데이터를 효율적으로 관리할 수 있다. 데이터 종속성\n데이터와 응용 프로그램이 상호 의존 관계를 말하며, 데이터의 구조가 변경되면 연관된 모든 응용 프로그램도 함께 수정되어야 한다는 것을 말한다. 스타일 상속\n자식 요소에서 별도로 스타일을 지정하지 않으면 부모 요소의 스타일 속성들이 자식요소로 전달되는 것이다.\n 반응형 웹 디자인\n웹 브라우저의 크기에 따라 화면 레이아웃을 자동으로 바꿔주는 방법이다.\n 프레임워크\n어떤 일을 처리하기위해 필요한 클래스와 라이브러리등이 합쳐진 형태이다. await \n작업 처리가 완료될때까지 코드 실행을 중지하고 기다린다. WAS(Web Application Server)\n웹 서버와 다르게 데이터베이스 조회와 같은 동적인 콘텐츠를 제공한다. fastAPI\n파이썬으로 API를 구축할 수 있게 해주는 웹 프레임워크이다\n nan 장영지 select_by_index\nselect 태그에서 특정 인덱스의 옵션을 선택하는데 사용한다. iframe\n웹 페이지 내에 다른 웹 페이지를 포함시키기 위해 사용하는 HTML 요소이다. scrollHeight\n웹 스크래핑 할 때 웹 페이지를 끝까지 스크롤 다운해야 그 다음 데이터를 조회하는 경우에 사용한다. parsing\n웹 페이지에서 내가 원하는 특정한 정보를 추출하는 기술이다. Wep Scraping \n웹 페이지의 정보를 수집하는 작업이다.\n 디버깅 순서\n구문 오류 확인, 변수 오류 확인, 업무 오류 확인(반복 입력 자동화) 순서로 디버깅을 한다.\n __name__\n파이썬 파일을 직접 실행할 경우 __name__에 __main__이라는 값이 설정되고, 다른 파일에서 불러와 사용하는 경우 모듈 이름이 설정된다. exception\n코드를 실행하는 중에 발생한 에러이다. cursor\nmongodb에서 collection의 내용을 찾을 때 그 위치값을 나타내는 포인터이다. Object Id\ndb에 데이터를 입력하면 자동으로 생성되고 수정이 불가하다. CRUD\nCreate, Read, Update, Delete 4가지의 데이터 처리 기능을 묶어서 일컫는 말이다.\n import\n만들어져 있는 모듈을 다른 파이썬 파일에서 사용할 수 있게 해주는 명령어이다. 논리연산자\nTrue인지 False인지 판단하는 연산자로\nand, or, not 이 있다.\n git 충돌\n같은 라인에 여러명이 동시에 작업을 했을 시, 충돌이 일어나고, 이를 해결하기 위해서는 마지막에 수정한 사용자가 merge를 해야 한다.'

# %%
# 조사 빼내기
import re
patterns = '(장영지|다양한|하거나|해야할|으로|에서|에는|위해|이를|이나|이다|있다|있게|되어|되고|되는|된다|까지|하지|하여|하고|하기|하게|하면|하며|하는|해야|한다|한지|로서|등 |할 |수 |서 |로 |때 |해 |의 |을 |를 |은 |과 |와 |에 |이 |가 |것|그 |\.|\,|\\n)'
text_regex = re.sub(pattern=patterns, repl=' ', string=text)
text_regex
# Out:
# '  자연어 처리(Natural Language Processing)  스케일링 서 다른 범위 값 가진 데이터들 범위 표준화시키는 과정   머신러닝 모델 특정 데이터 편향  학습    방지     pickle 파이썬 객체 자체 이진파일 저장  파이썬 모듈   대량 데이터 사용  복잡한 계산 처리    결과 저장 필요  다시 불러올     머신러닝 컴퓨터 데이터 학습해 규칙 찾아내는 과정   머신러닝 모델 학습 완료    모델 자체    판단  예측 수행       정규성 검증 데이터 정규 분포 따르는지 여부 확인  과정   데이터 분포 형태 확인해서  이후 진행 테스트 적절  판단   귀무가설 처음부터 기각   예상  세우는 가설   차이 없거나 유의미한 차이 없는 경우  대립가설 참임 증명    사용   pandas concat 동일한 컬럼 구조 가진 시리즈나 데이터프레임 하나 데이터셋  합칠  사용  함수   이상치 데이터 값 중 일반적인 분포  크게 벗어난 값 의미   이상치 식별  목적 정확한 분석   이러한 값들 데이터 미치는 영향 최소화  위함   datetime 날짜 시간 처리  있는 클래스 함수 제공  파이썬 모듈     사용  문자열 형태 날짜 데이터 실제 datetime 타입  변환  분석       value_counts() pandas  Series 각 유일한 값들 출현 빈도 계산  함수   데이터 분포 파악   가장 자주 나타나는 값 확인  사용   범주형 데이터 파악  사용 Matplotlib 파이썬  데이터 그래프나 차트 표현  시각화  라이브러리   데이터 분석 결과 한눈 이해  데이터 패턴 파악    사용   Pandas 파이썬  데이터 분석   사용  라이브러리   대량 데이터 빠르게 처리  분석    사용   판다스 외 데이터 분석   사용  라이브러리  NumPy  sklearn 등    DataFrame 2차원 배열 형태 데이터 구조로  여러 개 Series 모여 행 열 이루는 형태   각 열마다 다른 데이터 타입 가질  있으므로  여러 가지 타입 데이터 한 번 다루는 데 효과적   자바스크립트 브라우저  사용  자바스크립트는 웹 페이지 동적이고 상호작용 가능  만드는 프로그래밍 언어   클라이언트 측  코드 실행  서버 부하 감소시키기   사용   postman API 개발 위한 테스트 및 문서화 도와주는 플랫폼    목적 서버 들어온 API 요청 대해 제대 동작 지 확인  위함   Open API 누구나 사용  있도록 공개된 API     통 복잡한 기능 빠르게 구현   다른 서비스와 연동 간편  처리  있어  개발 시간 단축  효율성 높일     nan nan Uvicorn 비동기 처리 방식 지원  Python 웹 서버   HTTP 웹상  클라이언트 서버 간 요청/응답  데이터 주고 받  있는 프로토콜   클라이언트 서버 간에  혹 서버 서버 간 데이터 신속  안전  교환      웹 브라우저  애플리케이션  다른 서버    환경  통신 사용   commit 파일 변경사항 저장  작업    목적 코드 변경 이력 관리  추적  버전관리 협업 지원      데이터베이스 시스템 데이터 데이터베이스 저장  관리  시스템    목적 파일 시스템 문제점인 데이터 종속성 데이터 중복성 최소화    데이터 효율적  관리  위함   데이터 조작어 데이터베이스 안 데이터 조작  쓰는 명령어 집합   데이터 조작어 주요 목적 데이터베이스  정보 삽입  삭제  갱신  검색        통 사용자는 필요한 데이터 효율적  관리     데이터 종속성 데이터 응용 프로그램 상호 의존 관계 말   데이터 구조 변경되면 연관된 모든 응용 프로그램도 함께 수정 야  는   말   스타일 상속 자식 요소  별도 스타일 지정  않으면 부모 요소 스타일 속성들 자식요소 전달       반응형 웹 디자인 웹 브라우저 크기 따라 화면 레이아웃 자동  바꿔주는 방법    프레임워크 어떤 일 처리   필요한 클래스 라이브러리등 합쳐진 형태   await  작업 처리 완료될때  코드 실행 중지  기다린다  WAS(Web Application Server) 웹 서버 다르게 데이터베이스 조회 같 동적인 콘텐츠 제공   fastAPI 파이썬  API 구축    해주는 웹 프레임워크   nan   select_by_index select 태그  특정 인덱스 옵션 선택 데 사용   iframe 웹 페이지 내 다른 웹 페이지 포함시키기   사용  HTML 요소   scrollHeight 웹 스크래핑   웹 페이지 끝  스크롤 다운   다음 데이터 조회  경우 사용   parsing 웹 페이지  내 원  특정한 정보 추출  기술   Wep Scraping  웹 페이지 정보 수집  작업    디버깅 순서 구문 오류 확인  변 오류 확인  업무 오류 확인(반복 입력 자동화) 순서 디버깅     __name__ 파이썬 파일 직접 실행 경우 __name__ __main__이라는 값 설정   다른 파일  불러 사용  경우 모듈 이름 설정   exception 코드 실행  중 발생한 에러   cursor mongodb  collection 내용 찾   위치값 나타내는 포인터   Object Id db 데이터 입력  자동  생성  수정 불가하다  CRUD Create  Read  Update  Delete 4가지 데이터 처리 기능 묶어 일컫는 말    import 만들어져 있는 모듈 다른 파이썬 파일  사용    해주는 명령어   논리연산자 True인지 False인지 판단  연산자로 and  or  not      git 충돌 같 라인 여러명 동시 작업 했 시  충돌 일어나고    해결   서는 마지막 수정한 사용자 merge     '

# %%
# !apt-get -y install fonts-nanum
# !fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %%
from wordcloud import WordCloud
from collections import Counter

# %%
text_split = text_regex.split()
text_split_count = Counter(text_split)

# %%
top_30 = pd.Series(text_split_count).sort_values(ascending=False)[:30]

# %%
wordCloud = WordCloud(background_color='white', font_path='/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf')
wordCloud.generate_from_frequencies(top_30)

# %%
wordCloud.words_
# Out:
# {'데이터': 1.0,
#  '사용': 0.5428571428571428,
#  '웹': 0.37142857142857144,
#  '서버': 0.2571428571428571,
#  '처리': 0.22857142857142856,
#  '파이썬': 0.22857142857142856,
#  '다른': 0.2,
#  '페이지': 0.17142857142857143,
#  '분석': 0.17142857142857143,
#  'API': 0.14285714285714285,
#  '확인': 0.14285714285714285,
#  '형태': 0.14285714285714285,
#  '목적': 0.14285714285714285,
#  '데이터베이스': 0.14285714285714285,
#  '파일': 0.14285714285714285,
#  '값': 0.14285714285714285,
#  '모듈': 0.11428571428571428,
#  '저장': 0.11428571428571428,
#  '관리': 0.11428571428571428,
#  '경우': 0.11428571428571428,
#  '작업': 0.11428571428571428,
#  '실행': 0.11428571428571428,
#  '분포': 0.11428571428571428,
#  '코드': 0.11428571428571428,
#  '라이브러리': 0.08571428571428572,
#  '타입': 0.08571428571428572,
#  '브라우저': 0.08571428571428572,
#  'nan': 0.08571428571428572,
#  '있는': 0.08571428571428572,
#  '말': 0.08571428571428572}

# %%
import matplotlib.pyplot as plt
plt.imshow(wordCloud)
plt.axis('off')
plt.show()

# %% [markdown]
# # query 사용

# %% [markdown]
# ## wordcloud

# %%
import pandas as pd
import numpy as np

df_OWG = pd.read_excel('OneWord_Game.xlsx', sheet_name=None)

# %%
df_sheets = []
for sheet_name, df in df_OWG.items() :
  df_sheets.append(df)
  print(f'{sheet_name}, {type(df)}')
  pass

len(df_sheets)
# Out:
# 2월, <class 'pandas.core.frame.DataFrame'>
# 1월, <class 'pandas.core.frame.DataFrame'>
# 12월, <class 'pandas.core.frame.DataFrame'>
# 3

# %%
df_sheets[1].columns
# Out:
# Index([     '            ', 2024-01-31 00:00:00, 2024-01-30 00:00:00,
#        2024-01-29 00:00:00, 2024-01-26 00:00:00,            '1월 25일',
#                   '1월 24일',            '1월 23일',            '1월 22일',
#                   '1월 19일',            '1월 18일',            '1월 17일',
#                   '1월 16일',            '1월 15일',            '1월 12일',
#                   '1월 11일',            '1월 10일',             '1월 9일',
#                    '1월 8일',             '1월 5일',             '1월 4일',
#                    '1월 3일',             '1월 2일'],
#       dtype='object')

# %%
df_sheets[0].rename(columns={'            ': 'name'}, inplace=True)
df_sheets[1].rename(columns={'            ': 'name'}, inplace=True)
df_sheets[2].rename(columns={'      ': 'name'}, inplace=True)

# %%
contents_list = []
for x in range(len(df_sheets)) :
  condition = 'name=="장영지"'
  contents = df_sheets[x].query(condition).drop(columns='name').dropna(1).values.tolist()[0]
  contents_list.append(contents)
contents_list
# Out:
# <ipython-input-17-a61af6ef45df>:4: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only.
#   contents = df_sheets[x].query(condition).drop(columns='name').dropna(1).values.tolist()[0]
# <ipython-input-17-a61af6ef45df>:4: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only.
#   contents = df_sheets[x].query(condition).drop(columns='name').dropna(1).values.tolist()[0]
# <ipython-input-17-a61af6ef45df>:4: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only.
#   contents = df_sheets[x].query(condition).drop(columns='name').dropna(1).values.tolist()[0]
# [['자연어 처리(Natural Language Processing)\n',
#   '스케일링\n서로 다른 범위의 값을 가진 데이터들의 범위를 표준화시키는 과정이다. 머신러닝 모델이 특정 데이터에 편향되어 학습하는 것을 방지할 수 있다.',
#   'pickle\n파이썬 객체 자체를 이진파일로 저장하는 파이썬 모듈이다. 대량의 데이터를 사용하거나 복잡한 계산을 처리해야할 때 그 결과를 저장해 필요할 때 다시 불러올 수 있다.',
#   '머신러닝\n컴퓨터가 데이터를 학습해서 규칙을 찾아내는 과정이다. 머신러닝 모델이 학습을 완료하면, 그 모델 자체로서 다양한 판단이나 예측을 수행할 수 있게 된다.',
#   '정규성 검증\n데이터가 정규 분포를 따르는지 여부를 확인하는 과정이다. 데이터의 분포 형태를 확인해서, 이후에 진행할 테스트가 적절한지를 판단한다.',
#   '귀무가설\n처음부터 기각할 것을 예상하고 세우는 가설이다. 차이가 없거나 유의미한 차이가 없는 경우.\n대립가설이 참임을 증명하기 위해 사용한다.',
#   'pandas.concat\n동일한 컬럼 구조를 가진 시리즈나 데이터프레임을 하나의 데이터셋으로 합칠 때 사용하는 함수이다.',
#   '이상치\n데이터 값 중 일반적인 분포에서 크게 벗어난 값을 의미하며, 이상치를 식별하는 목적은 정확한 분석을 위해 이러한 값들이 데이터에 미치는 영향을 최소화하기 위함이다.',
#   'datetime\n날짜와 시간을 처리할 수 있는 클래스와 함수를 제공하는 파이썬 모듈이다. 이를 사용하면 문자열 형태의 날짜 데이터를 실제 datetime 타입으로 변환하여 분석할 수 있다.'],
#  ['value_counts()\npandas에서 Series의 각 유일한 값들의 출현 빈도를 계산하는 함수이다. 데이터의 분포를 파악하거나, 가장 자주 나타나는 값을 확인할 때 사용된다.\n범주형 데이터를 파악할 때 사용',
#   'Matplotlib\n파이썬에서 데이터를 그래프나 차트로 표현하여 시각화하는 라이브러리이다. 데이터 분석 결과를 한눈에 이해하고 데이터의 패턴을 파악하기 위해 사용한다.',
#   'Pandas\n파이썬에서 데이터 분석을 위해 사용되는 라이브러리이다. 대량의 데이터를 빠르게 처리, 분석하기 위해 사용한다. 판다스 외에 데이터 분석을 위해 사용하는 라이브러리에는 NumPy, sklearn 등이 있다.',
#   'DataFrame\n2차원 배열 형태의 데이터 구조로, 여러 개의 Series가 모여서 행과 열을 이루는 형태이다. 각 열마다 다른 데이터 타입을 가질 수 있으므로, 여러 가지 타입의 데이터를 한 번에 다루는 데 효과적이다.',
#   '자바스크립트\n브라우저에서 사용하는 자바스크립트는 웹 페이지를 동적이고 상호작용 가능하게 만드는 프로그래밍 언어이다. 클라이언트 측에서 코드를 실행하여 서버의 부하를 감소시키기 위해 사용한다.',
#   'postman\nAPI 개발을 위한 테스트 및 문서화를 도와주는 플랫폼이다. 그 목적은 서버가 들어온 API 요청에 대해서 제대로 동작하는지 확인하기 위함이다.',
#   'Open API\n누구나 사용할 수 있도록 공개된 API이다. 이를 통해 복잡한 기능을 빠르게 구현하거나, 다른 서비스와의 연동을 간편하게 처리할 수 있어, 개발 시간을 단축하고 효율성을 높일 수 있다.',
#   'Uvicorn\n비동기 처리 방식을 지원하는 Python 웹 서버이다.',
#   'HTTP\n웹상에서 클라이언트와 서버 간에 요청/응답으로 데이터를 주고 받을 수 있는 프로토콜이다. 클라이언트와 서버 간에, 혹은 서버와 서버 간에 데이터를 신속하고 안전하게 교환하는 것이다. 웹 브라우저, 애플리케이션, 다른 서버 등 다양한 환경에서의 통신에 사용된다.',
#   'commit\n파일의 변경사항을 저장하는 작업이다.\n그 목적은 코드 변경 이력을 관리하고 추적하여 버전관리와 협업을 지원하는 것이다.',
#   '데이터베이스 시스템\n데이터를 데이터베이스에 저장하고 관리하는 시스템이다.\n그 목적은 파일 시스템의 문제점인 데이터 종속성과 데이터 중복성을 최소화 하고, 데이터를 효율적으로 관리하기 위함이다.',
#   '데이터 조작어\n데이터베이스 안의 데이터를 조작할 때 쓰는 명령어의 집합이다.\n데이터 조작어의 주요 목적은 데이터베이스에서 정보를 삽입, 삭제, 갱신, 검색하는 것이다. 이를 통해 사용자는 필요한 데이터를 효율적으로 관리할 수 있다.',
#   '데이터 종속성\n데이터와 응용 프로그램이 상호 의존 관계를 말하며, 데이터의 구조가 변경되면 연관된 모든 응용 프로그램도 함께 수정되어야 한다는 것을 말한다.',
#   '스타일 상속\n자식 요소에서 별도로 스타일을 지정하지 않으면 부모 요소의 스타일 속성들이 자식요소로 전달되는 것이다.\n',
#   '반응형 웹 디자인\n웹 브라우저의 크기에 따라 화면 레이아웃을 자동으로 바꿔주는 방법이다.\n',
#   '프레임워크\n어떤 일을 처리하기위해 필요한 클래스와 라이브러리등이 합쳐진 형태이다.',
#   'await \n작업 처리가 완료될때까지 코드 실행을 중지하고 기다린다.',
#   'WAS(Web Application Server)\n웹 서버와 다르게 데이터베이스 조회와 같은 동적인 콘텐츠를 제공한다.',
#   'fastAPI\n파이썬으로 API를 구축할 수 있게 해주는 웹 프레임워크이다\n'],
#  ['select_by_index\nselect 태그에서 특정 인덱스의 옵션을 선택하는데 사용한다.',
#   'iframe\n웹 페이지 내에 다른 웹 페이지를 포함시키기 위해 사용하는 HTML 요소이다.',
#   'scrollHeight\n웹 스크래핑 할 때 웹 페이지를 끝까지 스크롤 다운해야 그 다음 데이터를 조회하는 경우에 사용한다.',
#   'parsing\n웹 페이지에서 내가 원하는 특정한 정보를 추출하는 기술이다.',
#   'Wep Scraping \n웹 페이지의 정보를 수집하는 작업이다.\n',
#   '디버깅 순서\n구문 오류 확인, 변수 오류 확인, 업무 오류 확인(반복 입력 자동화) 순서로 디버깅을 한다.\n',
#   '__name__\n파이썬 파일을 직접 실행할 경우 __name__에 __main__이라는 값이 설정되고, 다른 파일에서 불러와 사용하는 경우 모듈 이름이 설정된다.',
#   'exception\n코드를 실행하는 중에 발생한 에러이다.',
#   'cursor\nmongodb에서 collection의 내용을 찾을 때 그 위치값을 나타내는 포인터이다.',
#   'Object Id\ndb에 데이터를 입력하면 자동으로 생성되고 수정이 불가하다.',
#   'CRUD\nCreate, Read, Update, Delete 4가지의 데이터 처리 기능을 묶어서 일컫는 말이다.\n',
#   'import\n만들어져 있는 모듈을 다른 파이썬 파일에서 사용할 수 있게 해주는 명령어이다.',
#   '논리연산자\nTrue인지 False인지 판단하는 연산자로\nand, or, not 이 있다.\n',
#   'git 충돌\n같은 라인에 여러명이 동시에 작업을 했을 시, 충돌이 일어나고, 이를 해결하기 위해서는 마지막에 수정한 사용자가 merge를 해야 한다.']]

# %%
text = ' '.join(map(str, contents_list))
text
# Out:
# "['자연어 처리(Natural Language Processing)\\n', '스케일링\\n서로 다른 범위의 값을 가진 데이터들의 범위를 표준화시키는 과정이다. 머신러닝 모델이 특정 데이터에 편향되어 학습하는 것을 방지할 수 있다.', 'pickle\\n파이썬 객체 자체를 이진파일로 저장하는 파이썬 모듈이다. 대량의 데이터를 사용하거나 복잡한 계산을 처리해야할 때 그 결과를 저장해 필요할 때 다시 불러올 수 있다.', '머신러닝\\n컴퓨터가 데이터를 학습해서 규칙을 찾아내는 과정이다. 머신러닝 모델이 학습을 완료하면, 그 모델 자체로서 다양한 판단이나 예측을 수행할 수 있게 된다.', '정규성 검증\\n데이터가 정규 분포를 따르는지 여부를 확인하는 과정이다. 데이터의 분포 형태를 확인해서, 이후에 진행할 테스트가 적절한지를 판단한다.', '귀무가설\\n처음부터 기각할 것을 예상하고 세우는 가설이다. 차이가 없거나 유의미한 차이가 없는 경우.\\n대립가설이 참임을 증명하기 위해 사용한다.', 'pandas.concat\\n동일한 컬럼 구조를 가진 시리즈나 데이터프레임을 하나의 데이터셋으로 합칠 때 사용하는 함수이다.', '이상치\\n데이터 값 중 일반적인 분포에서 크게 벗어난 값을 의미하며, 이상치를 식별하는 목적은 정확한 분석을 위해 이러한 값들이 데이터에 미치는 영향을 최소화하기 위함이다.', 'datetime\\n날짜와 시간을 처리할 수 있는 클래스와 함수를 제공하는 파이썬 모듈이다. 이를 사용하면 문자열 형태의 날짜 데이터를 실제 datetime 타입으로 변환하여 분석할 수 있다.'] ['value_counts()\\npandas에서 Series의 각 유일한 값들의 출현 빈도를 계산하는 함수이다. 데이터의 분포를 파악하거나, 가장 자주 나타나는 값을 확인할 때 사용된다.\\n범주형 데이터를 파악할 때 사용', 'Matplotlib\\n파이썬에서 데이터를 그래프나 차트로 표현하여 시각화하는 라이브러리이다. 데이터 분석 결과를 한눈에 이해하고 데이터의 패턴을 파악하기 위해 사용한다.', 'Pandas\\n파이썬에서 데이터 분석을 위해 사용되는 라이브러리이다. 대량의 데이터를 빠르게 처리, 분석하기 위해 사용한다. 판다스 외에 데이터 분석을 위해 사용하는 라이브러리에는 NumPy, sklearn 등이 있다.', 'DataFrame\\n2차원 배열 형태의 데이터 구조로, 여러 개의 Series가 모여서 행과 열을 이루는 형태이다. 각 열마다 다른 데이터 타입을 가질 수 있으므로, 여러 가지 타입의 데이터를 한 번에 다루는 데 효과적이다.', '자바스크립트\\n브라우저에서 사용하는 자바스크립트는 웹 페이지를 동적이고 상호작용 가능하게 만드는 프로그래밍 언어이다. 클라이언트 측에서 코드를 실행하여 서버의 부하를 감소시키기 위해 사용한다.', 'postman\\nAPI 개발을 위한 테스트 및 문서화를 도와주는 플랫폼이다. 그 목적은 서버가 들어온 API 요청에 대해서 제대로 동작하는지 확인하기 위함이다.', 'Open API\\n누구나 사용할 수 있도록 공개된 API이다. 이를 통해 복잡한 기능을 빠르게 구현하거나, 다른 서비스와의 연동을 간편하게 처리할 수 있어, 개발 시간을 단축하고 효율성을 높일 수 있다.', 'Uvicorn\\n비동기 처리 방식을 지원하는 Python 웹 서버이다.', 'HTTP\\n웹상에서 클라이언트와 서버 간에 요청/응답으로 데이터를 주고 받을 수 있는 프로토콜이다. 클라이언트와 서버 간에, 혹은 서버와 서버 간에 데이터를 신속하고 안전하게 교환하는 것이다. 웹 브라우저, 애플리케이션, 다른 서버 등 다양한 환경에서의 통신에 사용된다.', 'commit\\n파일의 변경사항을 저장하는 작업이다.\\n그 목적은 코드 변경 이력을 관리하고 추적하여 버전관리와 협업을 지원하는 것이다.', '데이터베이스 시스템\\n데이터를 데이터베이스에 저장하고 관리하는 시스템이다.\\n그 목적은 파일 시스템의 문제점인 데이터 종속성과 데이터 중복성을 최소화 하고, 데이터를 효율적으로 관리하기 위함이다.', '데이터 조작어\\n데이터베이스 안의 데이터를 조작할 때 쓰는 명령어의 집합이다.\\n데이터 조작어의 주요 목적은 데이터베이스에서 정보를 삽입, 삭제, 갱신, 검색하는 것이다. 이를 통해 사용자는 필요한 데이터를 효율적으로 관리할 수 있다.', '데이터 종속성\\n데이터와 응용 프로그램이 상호 의존 관계를 말하며, 데이터의 구조가 변경되면 연관된 모든 응용 프로그램도 함께 수정되어야 한다는 것을 말한다.', '스타일 상속\\n자식 요소에서 별도로 스타일을 지정하지 않으면 부모 요소의 스타일 속성들이 자식요소로 전달되는 것이다.\\n', '반응형 웹 디자인\\n웹 브라우저의 크기에 따라 화면 레이아웃을 자동으로 바꿔주는 방법이다.\\n', '프레임워크\\n어떤 일을 처리하기위해 필요한 클래스와 라이브러리등이 합쳐진 형태이다.', 'await \\n작업 처리가 완료될때까지 코드 실행을 중지하고 기다린다.', 'WAS(Web Application Server)\\n웹 서버와 다르게 데이터베이스 조회와 같은 동적인 콘텐츠를 제공한다.', 'fastAPI\\n파이썬으로 API를 구축할 수 있게 해주는 웹 프레임워크이다\\n'] ['select_by_index\\nselect 태그에서 특정 인덱스의 옵션을 선택하는데 사용한다.', 'iframe\\n웹 페이지 내에 다른 웹 페이지를 포함시키기 위해 사용하는 HTML 요소이다.', 'scrollHeight\\n웹 스크래핑 할 때 웹 페이지를 끝까지 스크롤 다운해야 그 다음 데이터를 조회하는 경우에 사용한다.', 'parsing\\n웹 페이지에서 내가 원하는 특정한 정보를 추출하는 기술이다.', 'Wep Scraping \\n웹 페이지의 정보를 수집하는 작업이다.\\n', '디버깅 순서\\n구문 오류 확인, 변수 오류 확인, 업무 오류 확인(반복 입력 자동화) 순서로 디버깅을 한다.\\n', '__name__\\n파이썬 파일을 직접 실행할 경우 __name__에 __main__이라는 값이 설정되고, 다른 파일에서 불러와 사용하는 경우 모듈 이름이 설정된다.', 'exception\\n코드를 실행하는 중에 발생한 에러이다.', 'cursor\\nmongodb에서 collection의 내용을 찾을 때 그 위치값을 나타내는 포인터이다.', 'Object Id\\ndb에 데이터를 입력하면 자동으로 생성되고 수정이 불가하다.', 'CRUD\\nCreate, Read, Update, Delete 4가지의 데이터 처리 기능을 묶어서 일컫는 말이다.\\n', 'import\\n만들어져 있는 모듈을 다른 파이썬 파일에서 사용할 수 있게 해주는 명령어이다.', '논리연산자\\nTrue인지 False인지 판단하는 연산자로\\nand, or, not 이 있다.\\n', 'git 충돌\\n같은 라인에 여러명이 동시에 작업을 했을 시, 충돌이 일어나고, 이를 해결하기 위해서는 마지막에 수정한 사용자가 merge를 해야 한다.']"

# %%
# 조사 빼내기
import re
patterns = '(다양한|하거나|해야할|으로|에서|에는|위해|이를|이나|이다|있다|있게|되어|되고|되는|된다|까지|하지|하여|하고|하기|하게|하면|하며|하는|해야|한다|한지|로서|등 |할 |수 |서 |로 |때 |해 |의 |을 |를 |은 |과 |와 |에 |이 |가 |것|그 |\.|\,|\'|\[|\])'
text_regex = re.sub(pattern=patterns, repl=' ', string=text)
text_regex
# Out:
# '  자연어 처리(Natural Language Processing)\\n    스케일링\\n서 다른 범위 값 가진 데이터들 범위 표준화시키는 과정   머신러닝 모델 특정 데이터 편향  학습    방지        pickle\\n파이썬 객체 자체 이진파일 저장  파이썬 모듈   대량 데이터 사용  복잡한 계산 처리    결과 저장 필요  다시 불러올        머신러닝\\n컴퓨터 데이터 학습해 규칙 찾아내는 과정   머신러닝 모델 학습 완료    모델 자체    판단  예측 수행          정규성 검증\\n데이터 정규 분포 따르는지 여부 확인  과정   데이터 분포 형태 확인해서  이후 진행 테스트 적절  판단      귀무가설\\n처음부터 기각   예상  세우는 가설   차이 없거나 유의미한 차이 없는 경우 \\n대립가설 참임 증명    사용      pandas concat\\n동일한 컬럼 구조 가진 시리즈나 데이터프레임 하나 데이터셋  합칠  사용  함수      이상치\\n데이터 값 중 일반적인 분포  크게 벗어난 값 의미   이상치 식별  목적 정확한 분석   이러한 값들 데이터 미치는 영향 최소화  위함      datetime\\n날짜 시간 처리  있는 클래스 함수 제공  파이썬 모듈     사용  문자열 형태 날짜 데이터 실제 datetime 타입  변환  분석         value_counts()\\npandas  Series 각 유일한 값들 출현 빈도 계산  함수   데이터 분포 파악   가장 자주 나타나는 값 확인  사용  \\n범주형 데이터 파악  사용    Matplotlib\\n파이썬  데이터 그래프나 차트 표현  시각화  라이브러리   데이터 분석 결과 한눈 이해  데이터 패턴 파악    사용      Pandas\\n파이썬  데이터 분석   사용  라이브러리   대량 데이터 빠르게 처리  분석    사용   판다스 외 데이터 분석   사용  라이브러리  NumPy  sklearn 등       DataFrame\\n2차원 배열 형태 데이터 구조로  여러 개 Series 모여 행 열 이루는 형태   각 열마다 다른 데이터 타입 가질  있으므로  여러 가지 타입 데이터 한 번 다루는 데 효과적      자바스크립트\\n브라우저  사용  자바스크립트는 웹 페이지 동적이고 상호작용 가능  만드는 프로그래밍 언어   클라이언트 측  코드 실행  서버 부하 감소시키기   사용      postman\\nAPI 개발 위한 테스트 및 문서화 도와주는 플랫폼    목적 서버 들어온 API 요청 대해 제대 동작 지 확인  위함      Open API\\n누구나 사용  있도록 공개된 API     통 복잡한 기능 빠르게 구현   다른 서비스와 연동 간편  처리  있어  개발 시간 단축  효율성 높일        Uvicorn\\n비동기 처리 방식 지원  Python 웹 서버      HTTP\\n웹상  클라이언트 서버 간 요청/응답  데이터 주고 받  있는 프로토콜   클라이언트 서버 간에  혹 서버 서버 간 데이터 신속  안전  교환      웹 브라우저  애플리케이션  다른 서버    환경  통신 사용      commit\\n파일 변경사항 저장  작업  \\n 목적 코드 변경 이력 관리  추적  버전관리 협업 지원         데이터베이스 시스템\\n데이터 데이터베이스 저장  관리  시스템  \\n 목적 파일 시스템 문제점인 데이터 종속성 데이터 중복성 최소화    데이터 효율적  관리  위함      데이터 조작어\\n데이터베이스 안 데이터 조작  쓰는 명령어 집합  \\n데이터 조작어 주요 목적 데이터베이스  정보 삽입  삭제  갱신  검색        통 사용자는 필요한 데이터 효율적  관리        데이터 종속성\\n데이터 응용 프로그램 상호 의존 관계 말   데이터 구조 변경되면 연관된 모든 응용 프로그램도 함께 수정 야  는   말      스타일 상속\\n자식 요소  별도 스타일 지정  않으면 부모 요소 스타일 속성들 자식요소 전달     \\n    반응형 웹 디자인\\n웹 브라우저 크기 따라 화면 레이아웃 자동  바꿔주는 방법  \\n    프레임워크\\n어떤 일 처리   필요한 클래스 라이브러리등 합쳐진 형태      await \\n작업 처리 완료될때  코드 실행 중지  기다린다     WAS(Web Application Server)\\n웹 서버 다르게 데이터베이스 조회 같 동적인 콘텐츠 제공      fastAPI\\n파이썬  API 구축    해주는 웹 프레임워크 \\n     select_by_index\\nselect 태그  특정 인덱스 옵션 선택 데 사용      iframe\\n웹 페이지 내 다른 웹 페이지 포함시키기   사용  HTML 요소      scrollHeight\\n웹 스크래핑   웹 페이지 끝  스크롤 다운   다음 데이터 조회  경우 사용      parsing\\n웹 페이지  내 원  특정한 정보 추출  기술      Wep Scraping \\n웹 페이지 정보 수집  작업  \\n    디버깅 순서\\n구문 오류 확인  변 오류 확인  업무 오류 확인(반복 입력 자동화) 순서 디버깅   \\n    __name__\\n파이썬 파일 직접 실행 경우 __name__ __main__이라는 값 설정   다른 파일  불러 사용  경우 모듈 이름 설정      exception\\n코드 실행  중 발생한 에러      cursor\\nmongodb  collection 내용 찾   위치값 나타내는 포인터      Object Id\\ndb 데이터 입력  자동  생성  수정 불가하다     CRUD\\nCreate  Read  Update  Delete 4가지 데이터 처리 기능 묶어 일컫는 말  \\n    import\\n만들어져 있는 모듈 다른 파이썬 파일  사용    해주는 명령어      논리연산자\\nTrue인지 False인지 판단  연산자로\\nand  or  not    \\n    git 충돌\\n같 라인 여러명 동시 작업 했 시  충돌 일어나고    해결   서는 마지막 수정한 사용자 merge       '

# %%
# !apt-get -y install fonts-nanum
# !fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %%
from wordcloud import WordCloud
from collections import Counter

# %%
text_split = text_regex.split()
text_split_count = Counter(text_split)

# %%
top_30 = pd.Series(text_split_count).sort_values(ascending=False)[:30]

# %%
wordCloud = WordCloud(background_color='white', font_path='/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf')
wordCloud.generate_from_frequencies(top_30)

# %%
wordCloud.words_
# Out:
# {'데이터': 1.0,
#  '사용': 0.6333333333333333,
#  '\\n': 0.3,
#  '서버': 0.3,
#  '처리': 0.26666666666666666,
#  '웹': 0.23333333333333334,
#  '다른': 0.23333333333333334,
#  '분석': 0.2,
#  '페이지': 0.2,
#  '확인': 0.16666666666666666,
#  '형태': 0.16666666666666666,
#  '값': 0.16666666666666666,
#  '목적': 0.16666666666666666,
#  '저장': 0.13333333333333333,
#  '분포': 0.13333333333333333,
#  '경우': 0.13333333333333333,
#  '실행': 0.13333333333333333,
#  '모듈': 0.13333333333333333,
#  '데이터베이스': 0.13333333333333333,
#  '파일': 0.13333333333333333,
#  '관리': 0.13333333333333333,
#  '타입': 0.1,
#  'API': 0.1,
#  '함수': 0.1,
#  '스타일': 0.1,
#  '정보': 0.1,
#  '판단': 0.1,
#  '과정': 0.1,
#  '요소': 0.1,
#  '클라이언트': 0.1}

# %%
import matplotlib.pyplot as plt
plt.imshow(wordCloud)
plt.axis('off')
plt.show()
