# %% [markdown]
# <a href="https://colab.research.google.com/github/btg1631/study_AIs/blob/main/docs/quests/NLPs/wordcloud_korean_regexp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 한글 처리

# %%
# !apt-get -y install fonts-nanum
# !fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %% [markdown]
# ## 데이터 전처리

# %%
it_sentences = [
    "인공지능 기술이 사회의 다양한 분야에 점점 더 널리 적용되고 있다.",
    "클라우드 컴퓨팅은 데이터 저장과 처리를 더욱 효율적으로 만들어 주며, 기업의 IT 인프라를 혁신하고 있다.",
    "머신러닝과 딥러닝 알고리즘은 데이터 분석과 예측 모델링에 혁명을 일으키고 있다.",
    "블록체인 기술은 금융 거래의 투명성과 보안성을 향상시키는데 기여하고 있다.",
    "사이버 보안은 디지털 시대의 중요한 이슈로 부상하고 있으며, 지속적인 관심과 개선이 요구된다."
    # , "소프트웨어 개발에서의 애자일0 방법론은 빠른 시장 변화에 효과적으로 대응할 수 있게 해준다.",
    # "데이터 과학과 분석은 비즈니스 의사 결정 과정에서 중요한 역할을 하며, 기업의 경쟁력을 강화시킨다.",
    # "사물인터넷(IoT) 기술은 일상 생활을 더욱 편리하고 연결된 공간으로 변화시키고 있다.",
    # "가상현실(VR)과 증강현실(AR) 기술은 엔터테인먼트, 교육, 의료 등 다양한 분야에서 새로운 경험을 제공한다.",
    # "파이썬은 데이터 과학, 웹 개발, 자동화 스크립트 작성 등 다양한 프로그래밍 작업에 널리 사용되는 언어이다."
]

# %%
text = ' '.join(it_sentences)
text
# Out:
# '인공지능 기술이 사회의 다양한 분야에 점점 더 널리 적용되고 있다. 클라우드 컴퓨팅은 데이터 저장과 처리를 더욱 효율적으로 만들어 주며, 기업의 IT 인프라를 혁신하고 있다. 머신러닝과 딥러닝 알고리즘은 데이터 분석과 예측 모델링에 혁명을 일으키고 있다. 블록체인 기술은 금융 거래의 투명성과 보안성을 향상시키는데 기여하고 있다. 사이버 보안은 디지털 시대의 중요한 이슈로 부상하고 있으며, 지속적인 관심과 개선이 요구된다.'

# %%
# 조사 빼내기
import re
patterns = '(다양한|되고|하고|의 |은 |과 |에 |이 |\.)'
text_regex = re.sub(pattern=patterns, repl=' ', string=text)
text_regex
# Out:
# '인공지능 기술 사회   분야 점점 더 널리 적용  있다  클라우드 컴퓨팅 데이터 저장 처리를 더욱 효율적으로 만들어 주며, 기업 IT 인프라를 혁신  있다  머신러닝 딥러닝 알고리즘 데이터 분석 예측 모델링 혁명을 일으키고 있다  블록체인 기술 금융 거래 투명성 보안성을 향상시키는데 기여  있다  사이버 보안 디지털 시대 중요한 이슈로 부상  있으며, 지속적인 관심 개선 요구된다 '

# %%
text_split = text_regex.split()
text_split[:5], len(text_split)
# Out:
# (['인공지능', '기술', '사회', '분야', '점점'], 54)

# %%
from collections import Counter
text_split_count = Counter(text_split)
text_split_count

# %%
# !pip install wordcloud

# %% [markdown]
# ## 분석

# %%
from wordcloud import WordCloud

# %%
wordCloud = WordCloud(background_color='white', font_path='/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf')
wordCloud.generate_from_frequencies(text_split_count)

# %%
wordCloud.words_
# Out:
# {'있다': 1.0,
#  '기술': 0.5,
#  '데이터': 0.5,
#  '인공지능': 0.25,
#  '사회': 0.25,
#  '분야': 0.25,
#  '점점': 0.25,
#  '더': 0.25,
#  '널리': 0.25,
#  '적용': 0.25,
#  '클라우드': 0.25,
#  '컴퓨팅': 0.25,
#  '저장': 0.25,
#  '처리를': 0.25,
#  '더욱': 0.25,
#  '효율적으로': 0.25,
#  '만들어': 0.25,
#  '주며,': 0.25,
#  '기업': 0.25,
#  'IT': 0.25,
#  '인프라를': 0.25,
#  '혁신': 0.25,
#  '머신러닝': 0.25,
#  '딥러닝': 0.25,
#  '알고리즘': 0.25,
#  '분석': 0.25,
#  '예측': 0.25,
#  '모델링': 0.25,
#  '혁명을': 0.25,
#  '일으키고': 0.25,
#  '블록체인': 0.25,
#  '금융': 0.25,
#  '거래': 0.25,
#  '투명성': 0.25,
#  '보안성을': 0.25,
#  '향상시키는데': 0.25,
#  '기여': 0.25,
#  '사이버': 0.25,
#  '보안': 0.25,
#  '디지털': 0.25,
#  '시대': 0.25,
#  '중요한': 0.25,
#  '이슈로': 0.25,
#  '부상': 0.25,
#  '있으며,': 0.25,
#  '지속적인': 0.25,
#  '관심': 0.25,
#  '개선': 0.25,
#  '요구된다': 0.25}

# %%
import matplotlib.pyplot as plt
plt.imshow(wordCloud)
plt.axis('off')
plt.show()
